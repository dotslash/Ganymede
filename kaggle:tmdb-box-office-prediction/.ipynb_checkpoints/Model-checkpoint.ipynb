# %%
# Imports
import pandas
import numpy as np

import random
import ast

import xgboost as xgb
import lightgbm as lgb
import catboost as cat
from sklearn.model_selection import GroupKFold
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Prepare data

# %%
# ?/?/99 -> 1999
# ?/?/10 -> 2010
def GetReleaseYear(orig):
    if pandas.isna(orig):
        return 1900
    yr = int(orig.split('/')[2])
    if yr <= 19:
        return 2000 + yr
    else:
        return 1900 + yr
# xx/?/? -> xx
def GetReleaseMonth(orig):
    if pandas.isna(orig):
        return 0
    return int(orig.split('/')[0])
# '{..}' -> {..}
def GetDictionary(s):
    try:
        d = ast.literal_eval(s)
    except ValueError as err:
        if not pandas.isna(s):
            print("get_dictionary error: {}".format(err))
        d = {}    
    return d

def GetCountryCodes(raw):
    return [x.get('iso_3166_1', 'NA').lower() for x in GetDictionary(raw)]

def GetGenres(raw):
    return [x.get('name', 'NA').lower() for x in GetDictionary(raw)]

def GetProductionCompanies(raw):
    return [x.get('name', 'NA').lower().replace(' ', '_')
            for x in GetDictionary(raw)]

# Holder for state needed to convert raw data to 
# sample that can be used for prediction.
class TransformerState:
    def __init__(self):
        pass
    
def TransformAndFix(train, test):
    t_production_countries = train['production_countries'].apply(GetCountryCodes)
    t_genres = train['genres'].apply(GetGenres)    
    t_production_companies = train['production_companies'].apply(GetProductionCompanies)
    ret = TransformerState()
    ret.genres = pandas.Series(t_genres.sum()).value_counts()
    ret.countries = pandas.Series(t_production_countries.sum()).value_counts()
    ret.production_companies = pandas.Series(t_production_companies.sum()).value_counts()
    
    ret.genres = ret.genres[ret.genres > 50]
    ret.countries = ret.countries[ret.countries > 10]
    ret.production_companies = ret.production_companies[ret.production_companies > 10]

    for data in [train, test]:
        data['t_release_yr'] = data['release_date'].apply(GetReleaseYear)
        data['t_release_mo'] = data['release_date'].apply(GetReleaseMonth)
        for comp in ret.production_companies.keys():
            data['t_production_company_{}'.format(comp)] = \
                data['production_companies'].apply(lambda x: comp in GetProductionCompanies(x))

        for g in ret.genres.keys():
            data['t_genre_{}'.format(g)] = \
                data['genres'].apply(lambda x: g in GetGenres(x))
        for c in ret.countries.keys():
            data['t_production_country_{}'.format(c)] = \
                data['production_countries'].apply(lambda x: c in GetCountryCodes(x))
    return ret

# %%
train_orig = pandas.read_csv('data/train.csv')
test_orig = pandas.read_csv('data/test.csv')

train = train_orig.copy()
test = test_orig.copy()

# %%
transformer_state = TransformAndFix(train, test)

# %%
cols_to_skip = {'id', 'belongs_to_collection', 'genres', 'homepage',
             'imdb_id', 'original_language', 'original_title', 'overview',
             'production_companies', 'production_countries', 'release_date', 
             'runtime', 'spoken_languages', 'status', 'tagline', 'title', 
             'Keywords', 'cast', 'crew', 'poster_path', 'revenue'}
useful_columns = [c for c in train.columns if c not in cols_to_skip ]

# %%
train[useful_columns].head()
# Out:
#      budget  popularity  t_release_yr  t_release_mo  \
# 0  14000000    6.575393          2015             2
# 1  40000000    8.248895          2004             8
# 2   3300000   64.299990          2014            10
# 3   1200000    3.174936          2012             3
# 4         0    1.148070          2009             2
#
#    t_production_company_warner_bros.  t_production_company_universal_pictures  \
# 0                              False                                    False
# 1                              False                                    False
# 2                              False                                    False
# 3                              False                                    False
# 4                              False                                    False
#
#    t_production_company_paramount_pictures  \
# 0                                     True
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    t_production_company_twentieth_century_fox_film_corporation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    t_production_company_columbia_pictures  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    t_production_company_metro-goldwyn-mayer_(mgm)  ...  \
# 0                                            True  ...
# 1                                           False  ...
# 2                                           False  ...
# 3                                           False  ...
# 4                                           False  ...
#
#    t_production_country_ie  t_production_country_be  t_production_country_kr  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                     True
#
#    t_production_country_mx  t_production_country_se  t_production_country_nz  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    t_production_country_nl  t_production_country_cz  t_production_country_dk  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    t_production_country_br
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
#
# [5 rows x 113 columns]

# %%
test[useful_columns].head()
# Out:
#     budget  popularity  t_release_yr  t_release_mo  \
# 0        0    3.851534          2007             7
# 1    88000    3.559789          1958             5
# 2        0    8.085194          1997             5
# 3  6800000    8.596012          2010             9
# 4  2000000    3.217680          2005             2
#
#    t_production_company_warner_bros.  t_production_company_universal_pictures  \
# 0                              False                                    False
# 1                              False                                    False
# 2                               True                                    False
# 3                              False                                    False
# 4                              False                                    False
#
#    t_production_company_paramount_pictures  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    t_production_company_twentieth_century_fox_film_corporation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    t_production_company_columbia_pictures  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    t_production_company_metro-goldwyn-mayer_(mgm)  ...  \
# 0                                           False  ...
# 1                                           False  ...
# 2                                           False  ...
# 3                                           False  ...
# 4                                           False  ...
#
#    t_production_country_ie  t_production_country_be  t_production_country_kr  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    t_production_country_mx  t_production_country_se  t_production_country_nz  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    t_production_country_nl  t_production_country_cz  t_production_country_dk  \
# 0                    False                    False                    False
# 1                    False                    False                    False
# 2                    False                    False                    False
# 3                    False                    False                    False
# 4                    False                    False                    False
#
#    t_production_country_br
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
#
# [5 rows x 113 columns]

# %% [markdown]
# # Training

# %%
# Rmse.
def Score(actual, predicted):
    return np.sqrt(mean_squared_error(actual,  predicted))

# Returns log(revenue).
def GetY(data):
    return np.log1p(data["revenue"])

# - Splits the training data to n_splits
# - Fits the given model using each of the split as validation set and
#   the rest as training set. So it trains n_splits models
# - Predictions of the resultant model will be avegage of these n_splits
#   models
class KFoldValidationLearner():
    def __init__(self, data, n_splits=5):
        unique_vis = np.array(sorted(data['id'].unique()))
        folds = GroupKFold(n_splits)
        ids = np.arange(data.shape[0])
        
        self.fold_ids = []
        for train_ids, validation_ids in folds.split(X=unique_vis, y=unique_vis, groups=unique_vis):
            self.fold_ids.append([
                    ids[data['id'].isin(unique_vis[train_ids])],
                    ids[data['id'].isin(unique_vis[validation_ids])]
                ])
            
    def Learn(self, train, test,
              features, y_column,
              model, name,
              fit_params={"early_stopping_rounds": 500, "verbose": 100, "eval_metric": "rmse"}):
        full_score = 0
        test[name] = 0
        train[name] = np.NaN
        for fold_id, (trn, val) in enumerate(self.fold_ids):
            # Prepare training and validation data.
            devel = train[features].iloc[trn]
            y_devel = np.log1p(train[y_column].iloc[trn])
            valid = train[features].iloc[val]
            y_valid = np.log1p(train[y_column].iloc[val])
            # Train the model.
            model.fit(devel, y_devel, eval_set=[(valid, y_valid)], **fit_params)
            # Compute feature importance.
            if len(model.feature_importances_) != 0:
                model.FI = pandas.DataFrame(index=features)
                model.FI['fold' + str(fold_id)] = model.feature_importances_ / model.feature_importances_.sum()

            # Update predictions.
            predictions = model.predict(valid)
            predictions[predictions < 0] = 0
            test_predictions = model.predict(test[features])
            test_predictions[test_predictions < 0] = 0
            # Compute error using cross validaiton set.
            fold_score = Score(y_valid, predictions)
            full_score += fold_score / len(self.fold_ids)
            train[name].iloc[val] = predictions
            test[name] += test_predictions / len(self.fold_ids)
            print("Fold: ", fold_id, " Error: ", fold_score)
                
        print("Final score: ", full_score)
        return full_score

# %%
xgbmodel = xgb.XGBRegressor(max_depth=5, 
                            learning_rate=0.01, 
                            n_estimators=10000, 
                            objective='reg:linear', 
                            gamma=1.45, 
                            seed=random.randint(0, 10000),
                            silent=True,
                            subsample=0.8, 
                            colsample_bytree=0.7, 
                            colsample_bylevel=0.5)

catmodel = cat.CatBoostRegressor(iterations=10000, 
                                 learning_rate=0.01, 
                                 depth=5, 
                                 eval_metric='RMSE',
                                 colsample_bylevel=0.8,
                                 bagging_temperature = 0.2,
                                 metric_period = None,
                                 early_stopping_rounds=200,
                                 random_seed=random.randint(0, 10000))

lgbmodel = lgb.LGBMRegressor(n_estimators=10000, 
                             objective='regression', 
                             metric='rmse',
                             max_depth = 5,
                             num_leaves=30, 
                             min_child_samples=100,
                             learning_rate=0.01,
                             boosting = 'gbdt',
                             min_data_in_leaf= 10,
                             feature_fraction = 0.9,
                             bagging_freq = 1,
                             bagging_fraction = 0.9,
                             importance_type='gain',
                             lambda_l1 = 0.2,
                             bagging_seed=random.randint(0, 10000), 
                             subsample=.8, 
                             colsample_bytree=.9,
                             use_best_model=True)

# %%
kfold_learner = KFoldValidationLearner(train, 5)
kfold_learner.Learn(train, test, useful_columns, "revenue", xgbmodel, name="xgb")
# Out:
# [0]	validation_0-rmse:15.5723
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [100]	validation_0-rmse:6.11346
# [200]	validation_0-rmse:3.11399
# [300]	validation_0-rmse:2.43454
# [400]	validation_0-rmse:2.31743
# [500]	validation_0-rmse:2.29054
# [600]	validation_0-rmse:2.28018
# [700]	validation_0-rmse:2.27373
# [800]	validation_0-rmse:2.26935
# [900]	validation_0-rmse:2.26493
# [1000]	validation_0-rmse:2.26069
# [1100]	validation_0-rmse:2.25895
# [1200]	validation_0-rmse:2.25528
# [1300]	validation_0-rmse:2.2534
# [1400]	validation_0-rmse:2.25099
# [1500]	validation_0-rmse:2.24973
# [1600]	validation_0-rmse:2.24813
# [1700]	validation_0-rmse:2.24749
# [1800]	validation_0-rmse:2.248
# [1900]	validation_0-rmse:2.24608
# [2000]	validation_0-rmse:2.24566
# [2100]	validation_0-rmse:2.245
# [2200]	validation_0-rmse:2.24467
# [2300]	validation_0-rmse:2.24469
# [2400]	validation_0-rmse:2.24456
# [2500]	validation_0-rmse:2.24351
# [2600]	validation_0-rmse:2.24201
# [2700]	validation_0-rmse:2.24248
# [2800]	validation_0-rmse:2.24165
# [2900]	validation_0-rmse:2.24068
# [3000]	validation_0-rmse:2.24165
# [3100]	validation_0-rmse:2.24017
# [3200]	validation_0-rmse:2.24085
# [3300]	validation_0-rmse:2.24185
# [3400]	validation_0-rmse:2.2411
# [3500]	validation_0-rmse:2.24037
# [3600]	validation_0-rmse:2.24203
# Stopping. Best iteration:
# [3110]	validation_0-rmse:2.24013
#
# Fold:  0  Error:  2.240131410344093
# [0]	validation_0-rmse:15.5419
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [100]	validation_0-rmse:6.06082
# [200]	validation_0-rmse:2.97299
# [300]	validation_0-rmse:2.21687
# [400]	validation_0-rmse:2.08157
# [500]	validation_0-rmse:2.05015
# [600]	validation_0-rmse:2.04463
# [700]	validation_0-rmse:2.04053
# [800]	validation_0-rmse:2.04083
# [900]	validation_0-rmse:2.04036
# [1000]	validation_0-rmse:2.04115
# [1100]	validation_0-rmse:2.04323
# [1200]	validation_0-rmse:2.04332
# [1300]	validation_0-rmse:2.0467
# [1400]	validation_0-rmse:2.0492
# Stopping. Best iteration:
# [937]	validation_0-rmse:2.03954
#
# Fold:  1  Error:  2.039544432837551
# [0]	validation_0-rmse:15.7429
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [100]	validation_0-rmse:6.22204
# [200]	validation_0-rmse:3.00107
# [300]	validation_0-rmse:2.0941
# [400]	validation_0-rmse:1.87763
# [500]	validation_0-rmse:1.81705
# [600]	validation_0-rmse:1.79546
# [700]	validation_0-rmse:1.78256
# [800]	validation_0-rmse:1.77514
# [900]	validation_0-rmse:1.77123
# [1000]	validation_0-rmse:1.7662
# [1100]	validation_0-rmse:1.76183
# [1200]	validation_0-rmse:1.75847
# [1300]	validation_0-rmse:1.75798
# [1400]	validation_0-rmse:1.7565
# [1500]	validation_0-rmse:1.75677
# [1600]	validation_0-rmse:1.7559
# [1700]	validation_0-rmse:1.75789
# [1800]	validation_0-rmse:1.7592
# [1900]	validation_0-rmse:1.75993
# [2000]	validation_0-rmse:1.76159
# Stopping. Best iteration:
# [1568]	validation_0-rmse:1.75565
#
# Fold:  2  Error:  1.7556533350713384
# [0]	validation_0-rmse:15.65
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [100]	validation_0-rmse:6.14044
# [200]	validation_0-rmse:3.04285
# [300]	validation_0-rmse:2.27568
# [400]	validation_0-rmse:2.13341
# [500]	validation_0-rmse:2.09992
# [600]	validation_0-rmse:2.09023
# [700]	validation_0-rmse:2.08143
# [800]	validation_0-rmse:2.07373
# [900]	validation_0-rmse:2.06695
# [1000]	validation_0-rmse:2.0642
# [1100]	validation_0-rmse:2.06354
# [1200]	validation_0-rmse:2.0625
# [1300]	validation_0-rmse:2.06049
# [1400]	validation_0-rmse:2.05867
# [1500]	validation_0-rmse:2.05849
# [1600]	validation_0-rmse:2.05608
# [1700]	validation_0-rmse:2.05567
# [1800]	validation_0-rmse:2.05606
# [1900]	validation_0-rmse:2.05561
# [2000]	validation_0-rmse:2.05525
# [2100]	validation_0-rmse:2.05634
# [2200]	validation_0-rmse:2.05557
# [2300]	validation_0-rmse:2.05746
# [2400]	validation_0-rmse:2.05715
# Stopping. Best iteration:
# [1969]	validation_0-rmse:2.05465
#
# Fold:  3  Error:  2.0546549192548667
# [0]	validation_0-rmse:15.5364
# Will train until validation_0-rmse hasn't improved in 500 rounds.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# [100]	validation_0-rmse:6.11584
# [200]	validation_0-rmse:3.18264
# [300]	validation_0-rmse:2.52534
# [400]	validation_0-rmse:2.41118
# [500]	validation_0-rmse:2.39162
# [600]	validation_0-rmse:2.38422
# [700]	validation_0-rmse:2.379
# [800]	validation_0-rmse:2.36921
# [900]	validation_0-rmse:2.36378
# [1000]	validation_0-rmse:2.35861
# [1100]	validation_0-rmse:2.35458
# [1200]	validation_0-rmse:2.34681
# [1300]	validation_0-rmse:2.34141
# [1400]	validation_0-rmse:2.3372
# [1500]	validation_0-rmse:2.33452
# [1600]	validation_0-rmse:2.32706
# [1700]	validation_0-rmse:2.32494
# [1800]	validation_0-rmse:2.32497
# [1900]	validation_0-rmse:2.32354
# [2000]	validation_0-rmse:2.32467
# [2100]	validation_0-rmse:2.32309
# [2200]	validation_0-rmse:2.32424
# [2300]	validation_0-rmse:2.3232
# [2400]	validation_0-rmse:2.32281
# [2500]	validation_0-rmse:2.32052
# [2600]	validation_0-rmse:2.31826
# [2700]	validation_0-rmse:2.31936
# [2800]	validation_0-rmse:2.31833
# [2900]	validation_0-rmse:2.31831
# [3000]	validation_0-rmse:2.31693
# [3100]	validation_0-rmse:2.31698
# [3200]	validation_0-rmse:2.31655
# [3300]	validation_0-rmse:2.31705
# [3400]	validation_0-rmse:2.31825
# [3500]	validation_0-rmse:2.31769
# [3600]	validation_0-rmse:2.3192
# Stopping. Best iteration:
# [3142]	validation_0-rmse:2.31565
#
# Fold:  4  Error:  2.3156495913447688
# Final score:  2.0811267377705236
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 2.0811267377705236

# %%
kfold_learner.Learn(train, test, useful_columns, "revenue",
                 catmodel, name="cat",
                 fit_params={"use_best_model": True, "verbose": 500})
# Out:
# 0:	learn: 16.1050207	test: 16.0596311	best: 16.0596311 (0)	total: 57.8ms	remaining: 9m 37s
# 500:	learn: 2.1528678	test: 2.4160130	best: 2.4160130 (500)	total: 1.73s	remaining: 32.7s
# 1000:	learn: 1.9979237	test: 2.3037825	best: 2.3037825 (1000)	total: 3.13s	remaining: 28.1s
# 1500:	learn: 1.9243122	test: 2.2796307	best: 2.2796307 (1500)	total: 4.55s	remaining: 25.8s
# 2000:	learn: 1.8904303	test: 2.2684754	best: 2.2684747 (1999)	total: 6s	remaining: 24s
# 2500:	learn: 1.8630108	test: 2.2632373	best: 2.2632213 (2495)	total: 7.69s	remaining: 23.1s
# 3000:	learn: 1.8362914	test: 2.2616409	best: 2.2614486 (2908)	total: 9.31s	remaining: 21.7s
# 3500:	learn: 1.8137246	test: 2.2603985	best: 2.2601682 (3481)	total: 11s	remaining: 20.4s
# 4000:	learn: 1.7845600	test: 2.2580723	best: 2.2575651 (3896)	total: 12.5s	remaining: 18.8s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 2.257565125
# bestIteration = 3896
#
# Shrink model to first 3897 iterations.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Fold:  0  Error:  2.257565137171023
# 0:	learn: 16.1127576	test: 16.0302831	best: 16.0302831 (0)	total: 2.71ms	remaining: 27.1s
# 500:	learn: 2.2189852	test: 2.1557492	best: 2.1557492 (500)	total: 1.48s	remaining: 28s
# 1000:	learn: 2.1087079	test: 2.1004551	best: 2.1000472 (977)	total: 2.9s	remaining: 26.1s
# 1500:	learn: 2.0254842	test: 2.0638992	best: 2.0635519 (1492)	total: 4.25s	remaining: 24.1s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 2.05657409
# bestIteration = 1717
#
# Shrink model to first 1718 iterations.
# Fold:  1  Error:  2.056574115445471
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 0:	learn: 16.0635177	test: 16.2327844	best: 16.2327844 (0)	total: 2.86ms	remaining: 28.6s
# 500:	learn: 2.2628094	test: 1.9493639	best: 1.9493639 (500)	total: 1.71s	remaining: 32.4s
# 1000:	learn: 2.1095313	test: 1.8391961	best: 1.8390222 (998)	total: 3.31s	remaining: 29.8s
# 1500:	learn: 2.0416404	test: 1.8181130	best: 1.8180881 (1498)	total: 4.95s	remaining: 28s
# 2000:	learn: 2.0244379	test: 1.8157349	best: 1.8153446 (1836)	total: 6.43s	remaining: 25.7s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 1.815344585
# bestIteration = 1836
#
# Shrink model to first 1837 iterations.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Fold:  2  Error:  1.8153445818494933
# 0:	learn: 16.0859699	test: 16.1371937	best: 16.1371937 (0)	total: 2.67ms	remaining: 26.7s
# 500:	learn: 2.2014517	test: 2.1937599	best: 2.1937599 (500)	total: 1.57s	remaining: 29.9s
# 1000:	learn: 2.0260141	test: 2.1097985	best: 2.1097985 (1000)	total: 3.58s	remaining: 32.2s
# 1500:	learn: 1.9258000	test: 2.0778888	best: 2.0778521 (1497)	total: 5.26s	remaining: 29.8s
# 2000:	learn: 1.8880713	test: 2.0648511	best: 2.0648361 (1999)	total: 7.02s	remaining: 28.1s
# 2500:	learn: 1.8563198	test: 2.0558190	best: 2.0554143 (2475)	total: 9.01s	remaining: 27s
# 3000:	learn: 1.8278937	test: 2.0469785	best: 2.0469785 (3000)	total: 10.6s	remaining: 24.6s
# 3500:	learn: 1.8091954	test: 2.0427922	best: 2.0426817 (3472)	total: 12.1s	remaining: 22.5s
# 4000:	learn: 1.7955387	test: 2.0415772	best: 2.0414831 (3894)	total: 13.4s	remaining: 20.1s
# 4500:	learn: 1.7850612	test: 2.0409874	best: 2.0409178 (4391)	total: 14.8s	remaining: 18.1s
# 5000:	learn: 1.7738470	test: 2.0400624	best: 2.0400348 (4994)	total: 16.2s	remaining: 16.2s
# 5500:	learn: 1.7591560	test: 2.0391650	best: 2.0388528 (5365)	total: 17.5s	remaining: 14.3s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 2.0388528
# bestIteration = 5365
#
# Shrink model to first 5366 iterations.
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Fold:  3  Error:  2.038852802137937
# 0:	learn: 16.1154314	test: 16.0236178	best: 16.0236178 (0)	total: 2.81ms	remaining: 28.2s
# 500:	learn: 2.1189891	test: 2.4783066	best: 2.4783066 (500)	total: 1.89s	remaining: 35.8s
# 1000:	learn: 1.9973625	test: 2.4291247	best: 2.4290806 (999)	total: 3.71s	remaining: 33.3s
# 1500:	learn: 1.9279553	test: 2.3798735	best: 2.3797427 (1498)	total: 5.31s	remaining: 30.1s
# 2000:	learn: 1.8892206	test: 2.3561103	best: 2.3561012 (1995)	total: 7.07s	remaining: 28.3s
# 2500:	learn: 1.8594276	test: 2.3344742	best: 2.3344462 (2499)	total: 8.76s	remaining: 26.3s
# 3000:	learn: 1.8419727	test: 2.3252738	best: 2.3250764 (2929)	total: 10.4s	remaining: 24.3s
# 3500:	learn: 1.8289306	test: 2.3218732	best: 2.3218121 (3479)	total: 11.9s	remaining: 22.2s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 2.321812129
# bestIteration = 3479
#
# Shrink model to first 3480 iterations.
# Fold:  4  Error:  2.3218121314847644
# Final score:  2.098029753617738
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 2.098029753617738

# %%
kfold_learner.Learn(train, test, useful_columns, "revenue", lgbmodel, name="lgb")
# Out:
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's rmse: 2.50522
# [200]	valid_0's rmse: 2.35566
# [300]	valid_0's rmse: 2.30857
# [400]	valid_0's rmse: 2.29219
# [500]	valid_0's rmse: 2.2818
# [600]	valid_0's rmse: 2.27525
# [700]	valid_0's rmse: 2.27037
# [800]	valid_0's rmse: 2.26792
# [900]	valid_0's rmse: 2.26511
# [1000]	valid_0's rmse: 2.26444
# [1100]	valid_0's rmse: 2.26462
# [1200]	valid_0's rmse: 2.26375
# [1300]	valid_0's rmse: 2.2636
# [1400]	valid_0's rmse: 2.26388
# [1500]	valid_0's rmse: 2.26372
# [1600]	valid_0's rmse: 2.26374
# [1700]	valid_0's rmse: 2.26383
# [1800]	valid_0's rmse: 2.26331
# [1900]	valid_0's rmse: 2.26335
# [2000]	valid_0's rmse: 2.26307
# [2100]	valid_0's rmse: 2.26302
# [2200]	valid_0's rmse: 2.26338
# [2300]	valid_0's rmse: 2.26501
# [2400]	valid_0's rmse: 2.26458
# [2500]	valid_0's rmse: 2.2655
# [2600]	valid_0's rmse: 2.265
# Early stopping, best iteration is:
# [2183]	valid_0's rmse: 2.26264
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Fold:  0  Error:  2.2626446053858285
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's rmse: 2.23262
# [200]	valid_0's rmse: 2.08035
# [300]	valid_0's rmse: 2.03365
# [400]	valid_0's rmse: 2.02437
# [500]	valid_0's rmse: 2.02507
# [600]	valid_0's rmse: 2.02419
# [700]	valid_0's rmse: 2.02568
# [800]	valid_0's rmse: 2.02815
# [900]	valid_0's rmse: 2.02891
# Early stopping, best iteration is:
# [423]	valid_0's rmse: 2.02353
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Fold:  1  Error:  2.023526118303394
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's rmse: 2.03332
# [200]	valid_0's rmse: 1.85061
# [300]	valid_0's rmse: 1.80234
# [400]	valid_0's rmse: 1.78327
# [500]	valid_0's rmse: 1.7745
# [600]	valid_0's rmse: 1.77055
# [700]	valid_0's rmse: 1.76765
# [800]	valid_0's rmse: 1.76587
# [900]	valid_0's rmse: 1.76498
# [1000]	valid_0's rmse: 1.76481
# [1100]	valid_0's rmse: 1.76583
# [1200]	valid_0's rmse: 1.76627
# [1300]	valid_0's rmse: 1.76773
# [1400]	valid_0's rmse: 1.76856
# Early stopping, best iteration is:
# [992]	valid_0's rmse: 1.76441
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Fold:  2  Error:  1.7644060039649774
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's rmse: 2.27355
# [200]	valid_0's rmse: 2.12704
# [300]	valid_0's rmse: 2.08694
# [400]	valid_0's rmse: 2.07132
# [500]	valid_0's rmse: 2.0634
# [600]	valid_0's rmse: 2.05667
# [700]	valid_0's rmse: 2.05073
# [800]	valid_0's rmse: 2.04383
# [900]	valid_0's rmse: 2.04128
# [1000]	valid_0's rmse: 2.03681
# [1100]	valid_0's rmse: 2.03307
# [1200]	valid_0's rmse: 2.03028
# [1300]	valid_0's rmse: 2.03012
# [1400]	valid_0's rmse: 2.02803
# [1500]	valid_0's rmse: 2.02578
# [1600]	valid_0's rmse: 2.02648
# [1700]	valid_0's rmse: 2.02598
# [1800]	valid_0's rmse: 2.02861
# [1900]	valid_0's rmse: 2.02678
# [2000]	valid_0's rmse: 2.0271
# [2100]	valid_0's rmse: 2.02811
# Early stopping, best iteration is:
# [1687]	valid_0's rmse: 2.0254
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# Fold:  3  Error:  2.025404384541653
# Training until validation scores don't improve for 500 rounds.
# [100]	valid_0's rmse: 2.60493
# [200]	valid_0's rmse: 2.44438
# [300]	valid_0's rmse: 2.3907
# [400]	valid_0's rmse: 2.3626
# [500]	valid_0's rmse: 2.3462
# [600]	valid_0's rmse: 2.33873
# [700]	valid_0's rmse: 2.33422
# [800]	valid_0's rmse: 2.32622
# [900]	valid_0's rmse: 2.32458
# [1000]	valid_0's rmse: 2.32515
# [1100]	valid_0's rmse: 2.32462
# [1200]	valid_0's rmse: 2.32129
# [1300]	valid_0's rmse: 2.32055
# [1400]	valid_0's rmse: 2.31763
# [1500]	valid_0's rmse: 2.31524
# [1600]	valid_0's rmse: 2.31048
# [1700]	valid_0's rmse: 2.31201
# [1800]	valid_0's rmse: 2.31023
# [1900]	valid_0's rmse: 2.31193
# [2000]	valid_0's rmse: 2.30966
# [2100]	valid_0's rmse: 2.30589
# [2200]	valid_0's rmse: 2.30455
# [2300]	valid_0's rmse: 2.30117
# [2400]	valid_0's rmse: 2.29977
# [2500]	valid_0's rmse: 2.29906
# [2600]	valid_0's rmse: 2.30027
# [2700]	valid_0's rmse: 2.3007
# [2800]	valid_0's rmse: 2.30084
# [2900]	valid_0's rmse: 2.30031
# Early stopping, best iteration is:
# [2421]	valid_0's rmse: 2.299
# Fold:  4  Error:  2.2990018548829108
# Final score:  2.074996593415753
# /home/stps/.virtualenvs/kaggle3/lib/python3.6/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# 2.074996593415753

# %%
catmodel.FI.mean(axis=1).sort_values().tail(20).plot(
    kind="barh",
    title = "catmodel:Features Importance",
    figsize = (10,10))

# %%
lgbmodel.FI.mean(axis=1).sort_values().tail(20).plot(
    kind="barh",
    title = "catmodel:Features Importance",
    figsize = (10,10))

# %%
def DotSum(A, B):
    return sum(a*b for a,b in zip(A, B))

train['mix1'] = DotSum((0.4, 0.2, 0.4),
                       (train['xgb'], train['cat'], train['lgb']))
test['mix1'] = DotSum((0.4, 0.2, 0.4),
                      (test['xgb'], test['cat'], test['lgb']))

train['mix2'] = DotSum((0.34, 0.33, 0.33),
                      (train['xgb'], train['cat'], train['lgb']))
test['mix2'] = DotSum((0.34, 0.33, 0.33),
                      (test['xgb'], test['cat'], test['lgb']))

for model_name in ('mix1', 'mix2', 'xgb', 'lgb', 'cat'):
    print("RMSE model {}: {}".format(model_name, Score(GetY(train), train[model_name])))
# Out:
# RMSE model mix1: 2.0712638518037028
# RMSE model mix2: 2.070460293038064
# RMSE model xgb: 2.090171702477545
# RMSE model lgb: 2.083987502757196
# RMSE model cat: 2.105673560380915

# %% [markdown]
# # Submission

# %%
for model_name in ('mix1', 'mix2', 'xgb', 'lgb', 'cat'):
    print("Generating submission for ", model_name)
    test['revenue'] =  np.expm1(test[model_name])
    test[['id','revenue']].to_csv(
        'submissions/{}.csv'.format(model_name),
        index=False)
    print(test[['id','revenue']].head())
# Out:
# Generating submission for  mix1
#      id       revenue
# 0  3001  9.189113e+06
# 1  3002  1.564882e+06
# 2  3003  8.184719e+06
# 3  3004  2.221758e+06
# 4  3005  9.837272e+05
# Generating submission for  mix2
#      id       revenue
# 0  3001  7.397500e+06
# 1  3002  1.524833e+06
# 2  3003  7.540627e+06
# 3  3004  2.437073e+06
# 4  3005  9.423042e+05
# Generating submission for  xgb
#      id       revenue
# 0  3001  1.210779e+07
# 1  3002  1.198528e+06
# 2  3003  9.084592e+06
# 3  3004  1.803617e+06
# 4  3005  9.170419e+05
# Generating submission for  lgb
#      id       revenue
# 0  3001  1.356852e+07
# 1  3002  2.192420e+06
# 2  3003  9.482927e+06
# 3  3004  2.054813e+06
# 4  3005  1.199646e+06
# Generating submission for  cat
#      id       revenue
# 0  3001  2.427579e+06
# 1  3002  1.359139e+06
# 2  3003  4.949065e+06
# 3  3004  3.941399e+06
# 4  3005  7.611821e+05
